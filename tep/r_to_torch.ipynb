# %%
import pyreadr
import torch
import numpy as np

# %%
data = pyreadr.read_r("dataset/RData/TEP_FaultFree_Training.RData")
df = data[list(data.keys())[0]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = pyreadr.read_r("dataset/RData/TEP_FaultFree_Training.RData")
#       2 df = data[list(data.keys())[0]]
#
# File /scratch/users/bgunduz21/projects/fault-detection-kocsistem/.conda/lib/python3.12/site-packages/pyreadr/pyreadr.py:70, in read_r(path, use_objects, timezone)
#      68 result = OrderedDict()
#      69 for table_index, table in enumerate(parser.table_data):
# ---> 70     result[table.name] = table.convert_to_pandas_dataframe()
#      71 return result
#
# File /scratch/users/bgunduz21/projects/fault-detection-kocsistem/.conda/lib/python3.12/site-packages/pyreadr/_pyreadr_parser.py:55, in Table.convert_to_pandas_dataframe(self)
#      53     self._arraylike_todf()
#      54 else:
# ---> 55     self._dflike_todf()
#      56 return self.df
#
# ...

# %%
df[df["simulationRun"] == 5].head()
# Out:
#       faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  xmeas_4  \
# 2000          0.0            5.0       1  0.25071   3658.3   4472.2   9.3070
# 2001          0.0            5.0       2  0.25063   3638.9   4508.6   9.3893
# 2002          0.0            5.0       3  0.24981   3624.0   4515.8   9.3502
# 2003          0.0            5.0       4  0.25111   3641.8   4501.1   9.3038
# 2004          0.0            5.0       5  0.24711   3657.6   4526.1   9.4403
#
#       xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4   xmv_5   xmv_6  \
# 2000   26.504   42.278   2704.8  ...  54.424  24.625  63.544  21.868  40.109
# 2001   27.070   42.190   2704.4  ...  53.988  24.633  61.719  22.410  39.843
# 2002   27.185   42.488   2706.1  ...  53.902  24.721  62.464  22.430  40.096
# 2003   26.837   42.258   2706.1  ...  54.078  24.594  60.442  22.156  40.039
# 2004   27.215   42.192   2705.4  ...  54.327  24.351  60.756  22.433  39.093
#
# ...

# %%
data_np = df.to_numpy()
data_torch = torch.tensor(data_np)
torch.save(data_torch, "dataset/Torch/TEP_FaultFree_Training.torch")
